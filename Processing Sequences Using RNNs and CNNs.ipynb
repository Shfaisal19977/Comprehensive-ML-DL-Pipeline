# %%
from tensorflow.keras.layers import LSTM

# RNN Model Class
class RNNModel:
    def __init__(self, input_shape, n_classes):
        self.model = keras.Sequential([
            layers.InputLayer(input_shape=input_shape),
            layers.LSTM(128, return_sequences=True),
            layers.LSTM(64),
            layers.Dense(n_classes, activation='softmax')
        ])
        self.model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

    def train(self, X_train, y_train, X_val, y_val, epochs=10, batch_size=32):
        return self.model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(X_val, y_val))

    def evaluate(self, X_test, y_test):
        return self.model.evaluate(X_test, y_test)

# Usage Example Function
def run_rnn_model(X, y, input_shape=(50, 1), n_classes=10, epochs=10):
    X_train, X_test, y_train, y_test = prepare_data(X, y)

    rnn_model = RNNModel(input_shape=input_shape, n_classes=n_classes)
    rnn_model.train(X_train, y_train, X_test, y_test, epochs=epochs)

    print("Evaluation Results:", rnn_model.evaluate(X_test, y_test))

# Sample usage with custom dataset
# run_rnn_model(X, y, input_shape=(X_train.shape[1], X_train.shape[2]), n_classes=10, epochs=20)
