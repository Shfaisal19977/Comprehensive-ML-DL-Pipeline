# %%
from sklearn.ensemble import RandomForestClassifier

# Random Forest Model Class
class RandomForestModel:
    def __init__(self, n_estimators=100):
        self.model = RandomForestClassifier(n_estimators=n_estimators)

    def train(self, X_train, y_train):
        self.model.fit(X_train, y_train)

    def predict(self, X_test):
        return self.model.predict(X_test)

    def evaluate(self, y_test, y_pred):
        report = classification_report(y_test, y_pred)
        cm = confusion_matrix(y_test, y_pred)
        return report, cm

    def plot_confusion_matrix(self, cm):
        sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
        plt.xlabel('Predicted')
        plt.ylabel('Actual')
        plt.title('Confusion Matrix')
        plt.show()

# Usage Example Function
def run_random_forest_model(X, y, categorical_features=[], numerical_features=[], n_estimators=100):
    X_train, X_test, y_train, y_test = prepare_data(X, y, categorical_features=categorical_features, numerical_features=numerical_features)

    rf_model = RandomForestModel(n_estimators=n_estimators)
    rf_model.train(X_train, y_train)

    y_pred = rf_model.predict(X_test)

    report, cm = rf_model.evaluate(y_test, y_pred)
    print("Classification Report:\n", report)

    rf_model.plot_confusion_matrix(cm)

# Sample usage with custom dataset
# run_random_forest_model(X, y, categorical_features, numerical_features, n_estimators=100)
